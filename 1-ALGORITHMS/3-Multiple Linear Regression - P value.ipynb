# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

veriler=pd.read_csv("veriler.csv")
veriler.head()
# Out:
#   ulke  boy  kilo  yas cinsiyet
# 0   tr  130    30   10        e
# 1   tr  125    36   11        e
# 2   tr  135    34   10        k
# 3   tr  133    30    9        k
# 4   tr  129    38   12        e

# %% [markdown]
# # Dummy Variable(Kukla Değişken)

# %%
#encoding islemi = e->1 , k->0 gibi

# %%
ulke=veriler.iloc[:,0:1].values
from sklearn import preprocessing

le=preprocessing.LabelEncoder()
ulke[:,0]=le.fit_transform(veriler.iloc[:,0])

ohe=preprocessing.OneHotEncoder()
ulke=ohe.fit_transform(ulke).toarray()


"""
kısayol:

c=veriler.apply(preprocessing.LabelEncoder().fit_transform)
tüm satırlar label olur.
sonrasında concat ile birleştir.
"""
# Out:
# '\nkısayol:\n\nc=veriler.apply(preprocessing.LabelEncoder().fit_transform)\ntüm satırlar label olur.\nsonrasında concat ile birleştir.\n'

# %%
cinsiyet=veriler.iloc[:,-1:].values
from sklearn import preprocessing

le=preprocessing.LabelEncoder()
cinsiyet[:,-1]=le.fit_transform(veriler.iloc[:,-1])

ohe=preprocessing.OneHotEncoder()
cinsiyet=ohe.fit_transform(cinsiyet).toarray()

Yas=veriler.iloc[:,-4:-1].values

# %%
cinsiyet=cinsiyet[:,:1]

# %%
sonuc=pd.DataFrame(data=ulke,index=range(22),columns=['fr','tr','us'])

sonuc2=pd.DataFrame(data=Yas,index=range(22),columns=['boy','kilo','yas'])

#cinsiyet=veriler.iloc[:,-1].values
sonuc3=pd.DataFrame(data=cinsiyet,index=range(22),columns=['cinsiyet'])

# %%
s=pd.concat([sonuc,sonuc2],axis=1)
s2=pd.concat([s,sonuc3],axis=1)
s2
#encoding yapıldı s2 ile   veriler islenecek durumda
# Out:
#      fr   tr   us  boy  kilo  yas  cinsiyet
# 0   0.0  1.0  0.0  130    30   10       1.0
# 1   0.0  1.0  0.0  125    36   11       1.0
# 2   0.0  1.0  0.0  135    34   10       0.0
# 3   0.0  1.0  0.0  133    30    9       0.0
# 4   0.0  1.0  0.0  129    38   12       1.0
# 5   0.0  1.0  0.0  180    90   30       1.0
# 6   0.0  1.0  0.0  190    80   25       1.0
# 7   0.0  1.0  0.0  175    90   35       1.0
# 8   0.0  1.0  0.0  177    60   22       0.0
# 9   0.0  0.0  1.0  185   105   33       1.0
# 10  0.0  0.0  1.0  165    55   27       0.0
# 11  0.0  0.0  1.0  155    50   44       0.0
# 12  0.0  0.0  1.0  160    58   39       0.0
# 13  0.0  0.0  1.0  162    59   41       0.0
# 14  0.0  0.0  1.0  167    62   55       0.0
# 15  1.0  0.0  0.0  174    70   47       1.0
# 16  1.0  0.0  0.0  193    90   23       1.0
# 17  1.0  0.0  0.0  187    80   27       1.0
# 18  1.0  0.0  0.0  183    88   28       1.0
# 19  1.0  0.0  0.0  159    40   29       0.0
# ...

# %%
sonuc3
#encoding yapıldı ve DUMMY VARIABLE oldu
# Out:
#     cinsiyet
# 0        1.0
# 1        1.0
# 2        0.0
# 3        0.0
# 4        1.0
# 5        1.0
# 6        1.0
# 7        1.0
# 8        0.0
# 9        1.0
# 10       0.0
# 11       0.0
# 12       0.0
# 13       0.0
# 14       0.0
# 15       1.0
# 16       1.0
# 17       1.0
# 18       1.0
# 19       0.0
# 20       0.0
# 21       0.0

# %% [markdown]
# train

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(s,sonuc3,test_size=0.33,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(x_train)
Y_train=sc.fit_transform(y_train)

# %%
x_test
# Out:
#      fr   tr   us  boy  kilo  yas
# 20  1.0  0.0  0.0  164    66   32
# 10  0.0  0.0  1.0  165    55   27
# 14  0.0  0.0  1.0  167    62   55
# 13  0.0  0.0  1.0  162    59   41
# 1   0.0  1.0  0.0  125    36   11
# 21  1.0  0.0  0.0  166    56   42
# 11  0.0  0.0  1.0  155    50   44
# 19  1.0  0.0  0.0  159    40   29

# %%
x_train
# Out:
#      fr   tr   us  boy  kilo  yas
# 8   0.0  1.0  0.0  177    60   22
# 6   0.0  1.0  0.0  190    80   25
# 16  1.0  0.0  0.0  193    90   23
# 4   0.0  1.0  0.0  129    38   12
# 2   0.0  1.0  0.0  135    34   10
# 5   0.0  1.0  0.0  180    90   30
# 17  1.0  0.0  0.0  187    80   27
# 9   0.0  0.0  1.0  185   105   33
# 7   0.0  1.0  0.0  175    90   35
# 18  1.0  0.0  0.0  183    88   28
# 3   0.0  1.0  0.0  133    30    9
# 0   0.0  1.0  0.0  130    30   10
# 15  1.0  0.0  0.0  174    70   47
# 12  0.0  0.0  1.0  160    58   39

# %%
y_train
# Out:
#     cinsiyet
# 8        0.0
# 6        1.0
# 16       1.0
# 4        1.0
# 2        0.0
# 5        1.0
# 17       1.0
# 9        1.0
# 7        1.0
# 18       1.0
# 3        0.0
# 0        1.0
# 15       1.0
# 12       0.0

# %%
y_test
# Out:
#     cinsiyet
# 20       0.0
# 10       0.0
# 14       0.0
# 13       0.0
# 1        1.0
# 21       0.0
# 11       0.0
# 19       0.0

# %% [markdown]
# # Coklu Lineer Regresyon Kısmı

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
#tahmin kısmı

# %%
y_pred
# Out:
# array([[ 0.98720204],
#        [-0.12036863],
#        [ 0.05009703],
#        [ 0.07137418],
#        [ 0.72473935],
#        [ 0.64615044],
#        [-0.03567453],
#        [ 0.32612171]])

# %%
# boyu tahmin edeceğiz
boy=s2.iloc[:,3:4].values

sol=s2.iloc[:,:3]
sag=s2.iloc[:,4:]

veri=pd.concat([sol,sag],axis=1)

x_train,x_test,y_train,y_test=train_test_split(veri,boy,test_size=0.33,random_state=0)

regressor2 = LinearRegression()
regressor2.fit(x_train,y_train)
y_pred2=regressor2.predict(x_test)
y_pred2
# Out:
# array([[182.26638686],
#        [152.87161474],
#        [162.79386375],
#        [158.30668577],
#        [130.82888952],
#        [173.96138408],
#        [150.12782663],
#        [157.26898922]])

# %% [markdown]
# #  Backward Elimination-P value

# %%
import statsmodels.api as sm

# %%
X=np.append(arr = np.ones((22,1)).astype(int),values=veri,axis=1)
X
# Out:
# array([[  1.,   0.,   1.,   0.,  30.,  10.,   1.],
#        [  1.,   0.,   1.,   0.,  36.,  11.,   1.],
#        [  1.,   0.,   1.,   0.,  34.,  10.,   0.],
#        [  1.,   0.,   1.,   0.,  30.,   9.,   0.],
#        [  1.,   0.,   1.,   0.,  38.,  12.,   1.],
#        [  1.,   0.,   1.,   0.,  90.,  30.,   1.],
#        [  1.,   0.,   1.,   0.,  80.,  25.,   1.],
#        [  1.,   0.,   1.,   0.,  90.,  35.,   1.],
#        [  1.,   0.,   1.,   0.,  60.,  22.,   0.],
#        [  1.,   0.,   0.,   1., 105.,  33.,   1.],
#        [  1.,   0.,   0.,   1.,  55.,  27.,   0.],
#        [  1.,   0.,   0.,   1.,  50.,  44.,   0.],
#        [  1.,   0.,   0.,   1.,  58.,  39.,   0.],
#        [  1.,   0.,   0.,   1.,  59.,  41.,   0.],
#        [  1.,   0.,   0.,   1.,  62.,  55.,   0.],
#        [  1.,   1.,   0.,   0.,  70.,  47.,   1.],
#        [  1.,   1.,   0.,   0.,  90.,  23.,   1.],
#        [  1.,   1.,   0.,   0.,  80.,  27.,   1.],
# ...

# %%
X_l=veri.iloc[:,[0,1,2,3,4,5]].values
X_l=np.array(X_l,dtype=float)
model=sm.OLS(boy,X_l).fit()

model.summary()
# p degerine bak, amac en yuksek pyi elemek. Yani asagıda x5 elenecek
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     24.69
# Date:                Fri, 15 Oct 2021   Prob (F-statistic):           5.41e-07
# Time:                        21:37:50   Log-Likelihood:                -73.950
# No. Observations:                  22   AIC:                             159.9
# Df Residuals:                      16   BIC:                             166.4
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           114.0688      8.145     14.005      0.000      96.802     131.335
# ...

# %%
X_l=veri.iloc[:,[0,1,2,3,5]].values
X_l=np.array(X_l,dtype=float)
model=sm.OLS(boy,X_l).fit()

model.summary()
#r için 4.veri elendi
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     32.47
# Date:                Fri, 15 Oct 2021   Prob (F-statistic):           9.32e-08
# Time:                        21:37:50   Log-Likelihood:                -74.043
# No. Observations:                  22   AIC:                             158.1
# Df Residuals:                      17   BIC:                             163.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           115.6583      6.734     17.175      0.000     101.451     129.866
# ...
